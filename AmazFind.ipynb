# %%
import numpy as np
import pandas as pd

# %%
amazon_df = pd.read_csv('amazon_product.csv')

# %%
import nltk

# %%
amazon_df.sample(5)
# Out:
#        id                                              Title  \
# 117   385                         Looney Labs Anatomy Fluxx
# 149   488             Spy Gear - Ninja Attack - Ninja Stars
# 506  1900   Calplush Baby Rattles - Giraffe Plush Animal ...
# 178   608                Invisible Ink Mazing World of Fish
# 223   831           Masala Baby Baby Girls' Flutter 2pc Set
#
#                                            Description  \
# 117  Anatomy Fluxx is the newest addition to our ed...
# 149  Conduct spy missions with the Spy Gear Ninja A...
# 506  This wonderful Super soft and huggable plush i...
# 178  The Invisible Ink pen reveals the invisibly pr...
# 223  Two-piece top and bloomers set. Cute ruffles o...
#
#                                               Category
# 117                              Toys & Games › Games
# 149   Toys & Games › Novelty & Gag Toys › Spy Gadgets
# 506   Toys & Games Stuffed Animals & Plush Toys Stu...
# 178   Toys & Games Arts & Crafts Drawing & Painting...
# 223   Clothing, Shoes & Jewelry › Baby › Baby Girls...

# %%
amazon_df.head(5)
# Out:
#    id                                              Title  \
# 0   1   Swissmar Capstore Select Storage Rack for 18-...
# 1   2   Gemini200 Delta CV-880 Gold Crown Livery Airc...
# 2   5   Superior Threads 10501-2172 Magnifico Cream P...
# 3   6            Fashion Angels Color Rox Hair Chox Kit
# 4   8   Union Creative Giant Killing Figure 05: Daisu...
#
#                                          Description  \
# 0  Swissmar's capstore select 18 storage unit kee...
# 1  Welcome to the exciting world of GeminiJets! O...
# 2  For quilting and embroidery, this product is m...
# 3  Experiment with the haute trend of hair chalki...
# 4  From Union Creative. Turn your display shelf i...
#
#                                             Category
# 0   Home & Kitchen Kitchen & Dining Kitchen Utens...
# 1   Toys & Games Hobbies Models & Model Kits Pre-...
# 2   Arts, Crafts & Sewing Sewing Thread & Floss S...
# 3   Beauty & Personal Care Hair Care Hair Colorin...
# 4   Toys & Games › Action Figures & Statues › Sta...

# %%
amazon_df.drop('id', axis=1)
# Out:
#                                                  Title  \
# 0     Swissmar Capstore Select Storage Rack for 18-...
# 1     Gemini200 Delta CV-880 Gold Crown Livery Airc...
# 2     Superior Threads 10501-2172 Magnifico Cream P...
# 3              Fashion Angels Color Rox Hair Chox Kit
# 4     Union Creative Giant Killing Figure 05: Daisu...
# ..                                                 ...
# 663   Rosemery (Rosemary) - Box of Six 20 Stick Hex...
# 664   InterDesign Linus Stacking Organizer Bin, Ext...
# 665   Gourmet Rubber Stamps Diagonal Stripes Stenci...
# 666   Spenco RX Arch Cushion Full Length Comfort Su...
# 667                                           Car Kits
#
#                                            Description  \
# 0    Swissmar's capstore select 18 storage unit kee...
# 1    Welcome to the exciting world of GeminiJets! O...
# 2    For quilting and embroidery, this product is m...
# 3    Experiment with the haute trend of hair chalki...
# 4    From Union Creative. Turn your display shelf i...
# ..                                                 ...
# 663  Six tubes, each containing 20 sticks of incens...
# 664  The InterDesign Linus Organizer Bins are stack...
# 665  Gourmet Rubber Stamps-Stencil. This delicious ...
# 666  Soft, durable arch support. consumers with gen...
# 667                                       Kits for Car
#
#                                               Category
# 0     Home & Kitchen Kitchen & Dining Kitchen Utens...
# 1     Toys & Games Hobbies Models & Model Kits Pre-...
# 2     Arts, Crafts & Sewing Sewing Thread & Floss S...
# 3     Beauty & Personal Care Hair Care Hair Colorin...
# 4     Toys & Games › Action Figures & Statues › Sta...
# ..                                                 ...
# 663   Home & Kitchen Home Décor Home Fragrance Ince...
# 664   Home & Kitchen Kitchen & Dining Storage & Org...
# 665    Toys & Games Arts & Crafts Printing & Stamping
# 666   Health & Household › Health Care › Foot Healt...
# 667                                    Car Accessories
#
# [668 rows x 3 columns]

# %%
amazon_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 668 entries, 0 to 667
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           668 non-null    int64
#  1   Title        668 non-null    object
#  2   Description  668 non-null    object
#  3   Category     668 non-null    object
# dtypes: int64(1), object(3)
# memory usage: 21.0+ KB

# %%
from nltk.stem.snowball import SnowballStemmer
stemmer = SnowballStemmer('english')

# %%
def tokenize_stem(text):
    tokens = nltk.word_tokenize(text.lower())
    stems = []
    for words in tokens:
        stems.append(stemmer.stem(words))
    
    str = ' '.join(stems)
    return str

# %%
amazon_df['stemmed_tokens'] = amazon_df.apply(lambda row:tokenize_stem(row['Title'] + '' + row['Description']),axis = 1)

# %%
amazon_df.sample(3)
# Out:
#        id                                              Title  \
# 172   596          Little Tikes Spray and Rescue Fire Truck
# 359  1349   Logona Pressed No. 02 Powder, Medium Beige, 0...
# 181   636   Steve Madden Girls' Fashion Outerwear Jacket ...
#
#                                            Description  \
# 172                                   Durable Product
# 359  Compact powder with a delicate, satiny consist...
# 181  Always delivering on-point style, the Steve Ma...
#
#                                               Category  \
# 172   Toys & Games Toy Remote Control & Play Vehicl...
# 359         Beauty & Personal Care Makeup Face Powder
# 181   Clothing, Shoes & Jewelry Girls Clothing Jack...
#
#                                         stemmed_tokens
# 172  littl tike spray and rescu fire truck durabl p...
# 359  logona press no . 02 powder , medium beig , 0....
# 181  steve madden girl ' fashion outerwear jacket (...

# %%
amazon_df['stemmed_tokens']
# Out:
# 0      swissmar capstor select storag rack for 18-pac...
# 1      gemini200 delta cv-880 gold crown liveri aircr...
# 2      superior thread 10501-2172 magnifico cream puf...
# 3      fashion angel color rox hair chox kit experi w...
# 4      union creativ giant kill figur 05 : daisuk tsu...
#                              ...
# 663    rosemeri ( rosemari ) - box of six 20 stick he...
# 664    interdesign linus stack organ bin , extra larg...
# 665    gourmet rubber stamp diagon stripe stencil , 6...
# 666    spenco rx arch cushion full length comfort sup...
# 667                                  car kitskit for car
# Name: stemmed_tokens, Length: 668, dtype: object

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

tfidf = TfidfVectorizer(tokenizer=tokenize_stem)

# %%
def similarity(text1,text2):
    tfidf_matrix = tfidf.fit_transform([text1,text2])
    return cosine_similarity(tfidf_matrix)[0][1]

# %%
def product_search(query):
    stm_query = tokenize_stem(query)
    amazon_df['similarity'] = amazon_df['stemmed_tokens'].apply(lambda x:similarity(stm_query,x))
    res = amazon_df.sort_values(by=['similarity'],ascending=True).head(6)[["Title","Description","Category"]]
    return res

# %%
amazon_df.head(4)
# Out:
#    id                                              Title  \
# 0   1   Swissmar Capstore Select Storage Rack for 18-...
# 1   2   Gemini200 Delta CV-880 Gold Crown Livery Airc...
# 2   5   Superior Threads 10501-2172 Magnifico Cream P...
# 3   6            Fashion Angels Color Rox Hair Chox Kit
#
#                                          Description  \
# 0  Swissmar's capstore select 18 storage unit kee...
# 1  Welcome to the exciting world of GeminiJets! O...
# 2  For quilting and embroidery, this product is m...
# 3  Experiment with the haute trend of hair chalki...
#
#                                             Category  \
# 0   Home & Kitchen Kitchen & Dining Kitchen Utens...
# 1   Toys & Games Hobbies Models & Model Kits Pre-...
# 2   Arts, Crafts & Sewing Sewing Thread & Floss S...
# 3   Beauty & Personal Care Hair Care Hair Colorin...
#
#                                       stemmed_tokens
# 0  swissmar capstor select storag rack for 18-pac...
# 1  gemini200 delta cv-880 gold crown liveri aircr...
# 2  superior thread 10501-2172 magnifico cream puf...
# 3  fashion angel color rox hair chox kit experi w...

# %%
product_search('Capstore Select Storage Rack for 18-Pack')
# Out:
# c:\Users\DELL\anaconda3\lib\site-packages\sklearn\feature_extraction\text.py:525: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(
#                                                  Title  \
# 504                         Owl Rubber Duckys - 12 pc
# 241          Vitamin D3 1,000 IU, 250 softgels-Pack-3
# 633      Optoma BL-FP200B, P-VIP, 200W Projector Lamp
# 261   Premium Compatibles DR720-PCI Imaging Drum Un...
# 556   Vidal - Fruit Mix Bagnoschiuma Fragola e Mirt...
# 26                 William Marvy Shaving Mug, Plastic
#
#                                            Description  \
# 504                                 Owl Rubber Duckys
# 241          Vitamin D3 1,000 IU, 250 softgels-PACK-3
# 633                                   P-VIP 200W Lamp
# 261  Brother DR-720 DR720 Drum Unit 35K - GSA and T...
# 556  Vidal - Fruit Mix Bagnoschiuma Fragola e Mirti...
# 26   Marvy Plastic Shaving Mug. Hand made. Made in ...
#
#                                               Category
# 504    Toys & Games › Baby & Toddler Toys › Bath Toys
# 241   Health & Household Vitamins & Dietary Supplem...
# 633   Office Products Office Electronics Video Proj...
# 261   Office Products Office & School Supplies Prin...
# 556   Beauty & Personal Care › Personal Care › Bath...
# 26    Home & Kitchen › Kitchen & Dining › Dining & ...
